# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\320300\\Desktop\\deliveries.csv')
df.head(5)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over   ...    bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0   ...           0
# 1     2  DA Warner    S Dhawan  TS Mills              0   ...           0
# 2     3  DA Warner    S Dhawan  TS Mills              0   ...           0
# 3     4  DA Warner    S Dhawan  TS Mills              0   ...           0
# 4     5  DA Warner    S Dhawan  TS Mills              0   ...           0
#
# ...

# %% [markdown]
# ## Which Player is dismissed maximum by R Ashwin and How?

# %%
Ashwin_df= df[df['bowler']=='R Ashwin']   #filtering from a data frame
Ashwin_df
# Out:
#         match_id  inning           batting_team         bowling_team  over  \
# 39655        169       2        Kings XI Punjab  Chennai Super Kings     6
# 39656        169       2        Kings XI Punjab  Chennai Super Kings     6
# 39657        169       2        Kings XI Punjab  Chennai Super Kings     6
# 39658        169       2        Kings XI Punjab  Chennai Super Kings     6
# 39659        169       2        Kings XI Punjab  Chennai Super Kings     6
# 39660        169       2        Kings XI Punjab  Chennai Super Kings     6
# 39680        169       2        Kings XI Punjab  Chennai Super Kings    10
# 39681        169       2        Kings XI Punjab  Chennai Super Kings    10
# 39682        169       2        Kings XI Punjab  Chennai Super Kings    10
# 39683        169       2        Kings XI Punjab  Chennai Super Kings    10
# 39684        169       2        Kings XI Punjab  Chennai Super Kings    10
# ...

# %%
Player_df= Ashwin_df.groupby('player_dismissed')['player_dismissed'].count().idxmax()
Player_df
# Out:
# 'RV Uthappa'

# %%
Player_df= Ashwin_df.groupby('player_dismissed')['dismissal_kind'].value_counts().idxmax(axis=0,skipna=True)
Player_df
# Out:
# ('PA Patel', 'caught')

# %%
import pandas as pd
df=pd.read_csv?

# %%
df=pd.read_csv('C:\\Users\\320300\\Desktop\\matches.csv',index_col=['dl_applied'])
df
# Out:
#                id  season           city       date  \
# dl_applied
# 0               1    2017      Hyderabad   4/5/2017
# 0               2    2017           Pune   4/6/2017
# 0               3    2017         Rajkot   4/7/2017
# 0               4    2017         Indore   4/8/2017
# 0               5    2017      Bangalore   4/8/2017
# 0               6    2017      Hyderabad   4/9/2017
# 0               7    2017         Mumbai   4/9/2017
# 0               8    2017         Indore  4/10/2017
# 0               9    2017           Pune  4/11/2017
# 0              10    2017         Mumbai  4/12/2017
# 0              11    2017        Kolkata  4/13/2017
# 0              12    2017      Bangalore  4/14/2017
# 0              13    2017         Rajkot  4/14/2017
# 0              14    2017        Kolkata  4/15/2017
# 0              15    2017          Delhi  4/15/2017
# 0              16    2017         Mumbai  4/16/2017
# 0              17    2017      Bangalore  4/16/2017
# ...

# %%
df1=df.drop([0])
df1.head(5)
# Out:
#              id  season       city       date                  team1  \
# dl_applied
# 1            57    2017  Bangalore  5/17/2017    Sunrisers Hyderabad
# 1           100    2008      Delhi  5/17/2008       Delhi Daredevils
# 1           103    2008    Kolkata  5/18/2008  Kolkata Knight Riders
# 1           120    2009  Cape Town  4/19/2009        Kings XI Punjab
# 1           123    2009     Durban  4/21/2009        Kings XI Punjab
#
#                             team2            toss_winner toss_decision  \
# dl_applied
# 1           Kolkata Knight Riders  Kolkata Knight Riders         field
# 1                 Kings XI Punjab       Delhi Daredevils           bat
# 1             Chennai Super Kings  Kolkata Knight Riders           bat
# 1                Delhi Daredevils       Delhi Daredevils         field
# 1           Kolkata Knight Riders  Kolkata Knight Riders         field
#
#             result                 winner  win_by_runs  win_by_wickets  \
# dl_applied
# ...

# %%
Row_String_Values=~['Pune','Delhi']
df1[df1.team1.str.contains('|'.join(Row_String_Values))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-287-2b9033a925ca> in <module>()
# ----> 1 Row_String_Values=~['Pune','Delhi']
#       2 df1[df1.team1.str.contains('|'.join(Row_String_Values))]
#
# TypeError: bad operand type for unary ~: 'list'
