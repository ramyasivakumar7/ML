# %% [markdown]
# ### 1. In the given dataframe, find the solution to reverse the column name (left most column to right)

# %% [markdown]
# #### Method 1:

# %%
import pandas as pd
df123=pd.read_csv('C:\\Users\\320300\\Desktop\\matches.csv')
df123[df123.columns[::-1]]
# Out:
#                      umpire3                umpire2                umpire1  \
# 0                        NaN               NJ Llong            AY Dandekar
# 1                        NaN                 S Ravi         A Nand Kishore
# 2                        NaN              CK Nandan            Nitin Menon
# 3                        NaN          C Shamshuddin           AK Chaudhary
# 4                        NaN                    NaN                    NaN
# 5                        NaN               NJ Llong             A Deshmukh
# 6                        NaN              CK Nandan            Nitin Menon
# 7                        NaN          C Shamshuddin           AK Chaudhary
# 8                        NaN                 S Ravi            AY Dandekar
# 9                        NaN              CK Nandan            Nitin Menon
# 10                       NaN               NJ Llong             A Deshmukh
# ...

# %% [markdown]
# #### Method 2:

# %%
import pandas as pd
df123=pd.read_csv('C:\\Users\\320300\\Desktop\\matches.csv')
df123.iloc[:,::-1]
# Out:
#                      umpire3                umpire2                umpire1  \
# 0                        NaN               NJ Llong            AY Dandekar
# 1                        NaN                 S Ravi         A Nand Kishore
# 2                        NaN              CK Nandan            Nitin Menon
# 3                        NaN          C Shamshuddin           AK Chaudhary
# 4                        NaN                    NaN                    NaN
# 5                        NaN               NJ Llong             A Deshmukh
# 6                        NaN              CK Nandan            Nitin Menon
# 7                        NaN          C Shamshuddin           AK Chaudhary
# 8                        NaN                 S Ravi            AY Dandekar
# 9                        NaN              CK Nandan            Nitin Menon
# 10                       NaN               NJ Llong             A Deshmukh
# ...

# %% [markdown]
# #### Example 2

# %%
import pandas as pd
df123=pd.read_csv('C:\\Users\\320300\\Desktop\\matches.csv')
df123.iloc[0:3,3:8]   # iloc[row,column]
# Out:
#        date                team1                        team2  \
# 0  4/5/2017  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1  4/6/2017       Mumbai Indians       Rising Pune Supergiant
# 2  4/7/2017        Gujarat Lions        Kolkata Knight Riders
#
#                    toss_winner toss_decision
# 0  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders         field
